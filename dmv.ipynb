# %% [markdown]
# 1

# %%
import pandas as pd

sales_df = pd.read_csv('/home/leosama/bio_info/dmv/dataset/sales_data_sample.csv',encoding='unicode_escape')
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sales_df.shape
# Out:
# (2823, 25)

# %%
sales_df.to_json('/home/leosama/bio_info/dmv/dataset/sales.json')

# %%
sales_json_file = pd.read_json('/home/leosama/bio_info/dmv/dataset/sales.json')
sales_json_file.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue          None            NYC    NY
# ...

# %%
sales_df.to_excel('/home/leosama/bio_info/dmv/dataset/sales.xlsx',index=False)

# %%
sales_excel_file = pd.read_excel('/home/leosama/bio_info/dmv/dataset/sales.xlsx')
sales_excel_file.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sales_df.shape
# Out:
# (2823, 25)

# %%
sales_df.isna().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
sales_df.drop(columns=['ADDRESSLINE2','STATE'],inplace=True)

# %%
sales_df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: count, dtype: int64

# %%
x = sales_df[pd.isna(sales_df['TERRITORY'])]['COUNTRY']
set(x)
# Out:
# {'Canada', 'USA'}

# %%
label = 'AMERICAS'
import numpy as np
sales_df['TERRITORY'].replace(np.nan,label,inplace=True)

# %%
sales_df['TERRITORY'].unique()
# Out:
# array(['AMERICAS', 'EMEA', 'APAC', 'Japan'], dtype=object)

# %%
sales_df.dropna(inplace=True)

# %%
sales_df.shape
# Out:
# (2747, 23)

# %%
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 5        10168               36      96.66                1  3479.76
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0     Land of Toys Inc.        2125557818        897 Long Airport Avenue
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.lineplot(y=sales_df['SALES'],x = sales_df['YEAR_ID'])
plt.show()
# Out:
# /home/leosama/anaconda3/envs/timeseries/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/leosama/anaconda3/envs/timeseries/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x =sales_df['YEAR_ID'],y=sales_df['SALES'])
# Out:
# <Axes: xlabel='YEAR_ID', ylabel='SALES'>

# %%
top_cus = sales_df['CUSTOMERNAME'].value_counts()

plt.figure(figsize=(10,6))
top_cus[:5].plot(kind='bar', color='skyblue')
plt.show()

# %%
x = sales_df.groupby('YEAR_ID')['QUANTITYORDERED'].agg(['mean', 'min', 'max'])
x
# Out:
#               mean  min  max
# YEAR_ID
# 2003     34.600210   20   50
# 2004     34.833710   20   55
# 2005     36.903226    6   97

# %%
x.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Value')
plt.xticks(rotation=0)
plt.legend(title='Statistics')
plt.show()

# %% [markdown]
# 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
churn_df = pd.read_csv('/home/leosama/bio_info/dmv/dataset/telecom_customer_churn.csv')
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
columns = churn_df.columns

# %%
def get_sample(df,columns):

    result = {}
    for col in columns:
        result[col] = df[col][:5]

    return result

# %%
get_sample(churn_df,columns)
# Out:
# {'customerID': 0    7590-VHVEG
#  1    5575-GNVDE
#  2    3668-QPYBK
#  3    7795-CFOCW
#  4    9237-HQITU
#  Name: customerID, dtype: object,
#  'gender': 0    Female
#  1      Male
#  2      Male
#  3      Male
#  4    Female
#  Name: gender, dtype: object,
#  'SeniorCitizen': 0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: SeniorCitizen, dtype: int64,
#  'Partner': 0    Yes
#  1     No
#  2     No
#  3     No
#  4     No
#  Name: Partner, dtype: object,
#  'Dependents': 0    No
#  1    No
#  2    No
#  3    No
#  4    No
#  Name: Dependents, dtype: object,
#  'tenure': 0     1
#  1    34
#  2     2
#  3    45
#  4     2
#  Name: tenure, dtype: int64,
#  'PhoneService': 0     No
#  1    Yes
#  2    Yes
#  3     No
#  4    Yes
#  Name: PhoneService, dtype: object,
#  'MultipleLines': 0    No phone service
#  1                  No
#  2                  No
#  3    No phone service
#  4                  No
#  Name: MultipleLines, dtype: object,
# ...

# %%
churn_df.shape
# Out:
# (7043, 21)

# %%
import numpy as np
churn_df.replace(' ',np.nan,inplace=True)
churn_df.replace('?',np.nan,inplace=True)

# %%
churn_df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn_df['TotalCharges'] = pd.to_numeric(churn_df['TotalCharges'])
churn_df['TotalCharges'].fillna(churn_df['TotalCharges'].mean(),inplace=True)

# %%
numeric_col = []

for col in columns:
    if churn_df[col].dtype in ['int64' ,'float64']:
        numeric_col.append(col)

numeric_col = numeric_col[1:]
numeric_col
# Out:
# ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
def show_outliers(df,columns):
    plt.figure(figsize=(10,6 * len(columns)))

    for i,col in enumerate(columns):
        plt.subplot(len(columns),1,i+1)
        plt.boxplot(df[col])
        plt.title(f'boxplot of {col}')
        plt.xlabel(col)

    plt.tight_layout()
    plt.show()

# %%
show_outliers(churn_df,numeric_col)

# %%
churn_df['Tenure_years'] = churn_df['tenure'] / 12
churn_df['avg_charges_per_month'] = churn_df['TotalCharges'] / churn_df['tenure']

# %%
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
from sklearn.model_selection import train_test_split

columns = churn_df.columns

numeric_columns = []

for col in columns:
    if churn_df[col].dtype in ['int64','float64']:
        numeric_columns.append(col)

numeric_columns
# Out:
# ['SeniorCitizen',
#  'tenure',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Tenure_years',
#  'avg_charges_per_month']

# %%
churn_df.drop(columns='customerID',inplace=True)
columns = churn_df.columns

# %%
cat_columns = [col for col in columns if col not in numeric_columns]
cat_columns
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
from sklearn.preprocessing import LabelEncoder

X = churn_df.drop(columns='Churn')
y = churn_df['Churn']

label = LabelEncoder()

for col in cat_columns[:-1]:
    X[col] = label.fit_transform(X[col])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
churn_df.to_csv('filtered.csv',index=False)

# %% [markdown]
# 4

# %%
import pandas as pd

real_estate_df = pd.read_csv('/home/leosama/bio_info/dmv/dataset/Bengaluru_House_Data.csv')
real_estate_df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
real_estate_df.shape
# Out:
# (13320, 9)

# %%
columns = real_estate_df.columns
columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
real_estate_df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
real_estate_df.drop(columns='society',inplace=True)

# %%
cols = ['balcony','bath']
for col in cols:
    real_estate_df[col] = real_estate_df[col].fillna(real_estate_df[col].mean())

# %%
real_estate_df.dropna(inplace=True)
real_estate_df.shape
# Out:
# (13303, 8)

# %%
real_estate_df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
filtered_df = real_estate_df[(real_estate_df['area_type']=='Super built-up  Area') & (real_estate_df['availability']=='Ready To Move')]

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13303 entries, 0 to 13319
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13303 non-null  object
#  1   availability  13303 non-null  object
#  2   location      13303 non-null  object
#  3   size          13303 non-null  object
#  4   total_sqft    13303 non-null  object
#  5   bath          13303 non-null  float64
#  6   balcony       13303 non-null  float64
#  7   price         13303 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 935.4+ KB

# %%
real_estate_df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
real_estate_df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        '19-May', '17-Nov', '20-Oct', '20-Jun', '19-Feb', '21-Oct',
#        '21-Jan', '17-Mar', '17-Apr', '22-May', '19-Oct', '21-Jul',
#        '21-Nov', '21-Mar', '16-Dec', '22-Mar', '20-Jan', '21-Sep',
#        '21-Aug', '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun',
#        '17-Feb', '20-Nov', '20-Jul', '16-Sep', '15-Oct', '15-Dec',
#        '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov', '20-Apr',
#        '16-Jan', '14-Jul'], dtype=object)

# %%
real_estate_df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
s = '34.56Sq. Meter'
index = s.find('Sq. Meter')
x = s[:index]
float(x)*9
# Out:
# 311.04

# %%
for i,value in enumerate(real_estate_df['total_sqft']):
    tokens = str(value).split('-')

    if len(tokens) == 2:

        val = (float(tokens[0]) + float(tokens[1])) / 2
        real_estate_df['total_sqft'].replace(value,int(val),inplace=True)


    if 'Sq. Meter' in str(value):

        index = str(value).find('Sq. Meter')
        val = value[:index]
        val = float(val)*10.7
        real_estate_df['total_sqft'].replace(value,int(val),inplace=True)

    if 'Sq. Yards' in str(value):

        index = str(value).find('Sq. Yards')
        val = value[:index]
        val = float(val)*9
        real_estate_df['total_sqft'].replace(value,int(val),inplace=True)

#Sq. Meter
#Sq. Yards

# %%
for i in real_estate_df['total_sqft']:
    if len(str(i)) > 7:
        print(i)

# %%
unwanted_units = ['Perch', 'Acres', 'Guntha', 'Cents', 'Grounds']


for i,value in real_estate_df['total_sqft'].items():

    if any(unit in str(value) for unit in unwanted_units):
        real_estate_df.drop(index=i,inplace=True)


real_estate_df.reset_index(drop=True,inplace=True)

# %%
real_estate_df.shape
# Out:
# (13289, 8)

# %%
real_estate_df['total_sqft'] = pd.to_numeric(real_estate_df['total_sqft'])

# %%
real_estate_df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13284        Built-up  Area  Ready To Move                Whitefield
# 13285  Super built-up  Area  Ready To Move             Richards Town
# 13286        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13287  Super built-up  Area         18-Jun           Padmanabhanagar
# 13288  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  total_sqft  bath   balcony   price
# 0          2 BHK      1056.0   2.0  1.000000   39.07
# ...

# %%
real_estate_df.groupby('area_type')['price'].agg(['mean','std'])
# Out:
#                             mean         std
# area_type
# Built-up  Area        104.219005  109.243893
# Carpet  Area           89.502356   73.446012
# Plot  Area            209.619795  254.436982
# Super built-up  Area   92.972550  113.977674

# %% [markdown]
# 5

# %%
import pandas as pd

air_quality_df = pd.read_csv('/home/leosama/bio_info/dmv/dataset/City_Air_Quality.csv')
air_quality_df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
air_quality_df.tail()
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %%
air_quality_df[air_quality_df['AQI']>500]
# Out:
#             City        Date   PM2.5    PM10     NO     NO2    NOx   NH3  \
# 30     Ahmedabad  2015-01-31   94.52     NaN  24.39   32.66  52.61   NaN
# 31     Ahmedabad  2015-02-01  135.99     NaN  43.48   42.08  84.57   NaN
# 32     Ahmedabad  2015-02-02  178.33     NaN  54.56   35.31  72.80   NaN
# 33     Ahmedabad  2015-02-03  139.70     NaN  30.61   28.40  56.73   NaN
# 43     Ahmedabad  2015-02-13  103.36     NaN  18.18   39.56  57.33   NaN
# ...          ...         ...     ...     ...    ...     ...    ...   ...
# 25195      Patna  2019-01-22  313.62     NaN  48.09  188.74  78.51   NaN
# 26374    Talcher  2018-11-27  110.22  528.30  21.49    0.32  21.42  6.88
# 26377    Talcher  2018-11-30  100.66  507.65  23.27    0.10  22.40  6.98
# 26453    Talcher  2019-02-14  129.55  567.83  31.84     NaN  27.07  7.46
# 26720    Talcher  2019-11-08   57.45  493.34  39.71    1.90  40.38  8.35
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# ...

# %%
air_quality_df.shape
# Out:
# (29531, 16)

# %%
air_quality_df.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
air_quality_df['Date'] = pd.to_datetime(air_quality_df['Date'])

# %%
columns = air_quality_df.columns[2:15]
columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI'],
#       dtype='object')

# %%
for col in columns:

    air_quality_df[col].fillna(air_quality_df[col].mean(),inplace=True)

# %%
air_quality_df.head()
# Out:
#         City       Date      PM2.5        PM10     NO    NO2    NOx  \
# 0  Ahmedabad 2015-01-01  67.450578  118.127103   0.92  18.22  17.15
# 1  Ahmedabad 2015-01-02  67.450578  118.127103   0.97  15.69  16.46
# 2  Ahmedabad 2015-01-03  67.450578  118.127103  17.40  19.30  29.70
# 3  Ahmedabad 2015-01-04  67.450578  118.127103   1.70  18.48  17.97
# 4  Ahmedabad 2015-01-05  67.450578  118.127103  22.10  21.42  37.76
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0  23.483476   0.92  27.64  133.36     0.00     0.02    0.00  166.463581
# 1  23.483476   0.97  24.55   34.06     3.68     5.50    3.77  166.463581
# 2  23.483476  17.40  29.07   30.70     6.80    16.40    2.25  166.463581
# 3  23.483476   1.70  18.59   36.08     4.43    10.14    1.00  166.463581
# 4  23.483476  22.10  39.33   39.31     7.01    18.89    2.78  166.463581
#
#   AQI_Bucket
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ah_df = air_quality_df[air_quality_df['City']=='Ahmedabad']

result = ah_df.groupby('Date')['AQI'].first()

plt.figure(figsize=(20,8))
plt.plot(result.index,result.values)
# plt.xlabel('')

# %%
ah_df = air_quality_df[air_quality_df['City']=='Delhi']

result = ah_df.groupby('Date')['AQI'].first()

plt.figure(figsize=(20,8))
plt.plot(result.index,result.values)

# %%
ah_df = air_quality_df[air_quality_df['City']=='Delhi']

result = ah_df.groupby('Date')['PM10'].first()

plt.figure(figsize=(20,8))
plt.plot(result.index,result.values)

# %%
ah_df = air_quality_df[air_quality_df['City']=='Delhi']

result = ah_df.groupby('Date')['PM2.5'].first()

plt.figure(figsize=(20,8))
plt.plot(result.index,result.values)

# %%
sns.boxplot(air_quality_df[['PM2.5','PM10','NO2']])

plt.show()

# %%
sns.scatterplot(air_quality_df,x='AQI',y='PM10',label='PM10',color='red')
sns.scatterplot(air_quality_df,x='AQI',y='PM2.5',label='PM2.5',color='green')

plt.legend()
plt.show()

# %% [markdown]
# 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
retail_df = pd.read_csv('/home/leosama/bio_info/dmv/dataset/customer_shopping_data.csv')
retail_df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
retail_df.isna().sum()
retail_df.shape
# Out:
# (99457, 10)

# %%
retail_df['total_sale'] = retail_df['quantity'] * retail_df['price']
retail_df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  total_sale
# 0    Credit Card     5/8/2022          Kanyon     7502.00
# 1     Debit Card   12/12/2021  Forum Istanbul     5401.53
# 2           Cash    9/11/2021       Metrocity      300.08
# 3    Credit Card   16/05/2021    Metropol AVM    15004.25
# 4           Cash   24/10/2021          Kanyon      242.40

# %%
sale_by_region = retail_df.groupby('shopping_mall')['total_sale'].sum()
sale_by_region
# Out:
# shopping_mall
# Cevahir AVM          12645138.20
# Emaar Square Mall    12406100.29
# Forum Istanbul       12303921.24
# Istinye Park         24618827.68
# Kanyon               50554231.10
# Mall of Istanbul     50872481.68
# Metrocity            37302787.33
# Metropol AVM         25379913.19
# Viaport Outlet       12521339.72
# Zorlu Center         12901053.82
# Name: total_sale, dtype: float64

# %%
import seaborn as sns

plt.figure(figsize=(15,6))
sns.barplot(x = sale_by_region.index,y=sale_by_region.sort_values().values)
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
sales = retail_df.groupby(['shopping_mall','category'])['total_sale'].first()

sales_df = sales.reset_index()

plt.figure(figsize=(13,6))
sns.barplot(x=sales_df['shopping_mall'],y=sales_df['total_sale'],hue=sales_df['category'])
plt.show()

# %% [markdown]
# 2

# %%
import requests
import pandas as pd

# %%
lat = 19.0211
lon = 72.5134

# %%
api_key = "14b01e724014c68826132595f1214a55"
api_url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"

# %%
response = requests.get(api_url)
weather_data = response.json()
weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1731250800,
#    'main': {'temp': 303.2,
#     'feels_like': 307.83,
#     'temp_min': 301.59,
#     'temp_max': 303.2,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1012,
#     'humidity': 68,
#     'temp_kf': 1.61},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.96, 'deg': 339, 'gust': 5.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-10 15:00:00'},
#   {'dt': 1731261600,
#    'main': {'temp': 302.69,
#     'feels_like': 306.67,
#     'temp_min': 301.68,
#     'temp_max': 302.69,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1012,
#     'humidity': 68,
#     'temp_kf': 1.01},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
# ...

# %%
temperature =  [item['main']['temp'] for item in weather_data['list']]
temperature[-1]
# Out:
# 302.19

# %%
humidity =  [item['main']['humidity'] for item in weather_data['list']]
humidity[-1]
# Out:
# 71

# %%
wind_speed = [item['wind']['speed'] for item in weather_data['list']]
wind_speed[-1]
# Out:
# 5.4

# %%
weather_desc = [item['weather'][0]['description'] for item in weather_data['list']]
weather_desc[-1]
# Out:
# 'scattered clouds'

# %%
date_time = [item['dt_txt'] for item in weather_data['list']]
date_time[-1]
# Out:
# '2024-11-14 15:00:00'

# %%
weather_df = pd.DataFrame({'date_time':date_time,
                          'temperature':temperature,
                          'humidity':humidity,
                          'wind_speed':wind_speed,
                          'weather_description':weather_desc})


weather_df.head()
# Out:
#              date_time  temperature  humidity  wind_speed weather_description
# 0  2024-11-09 18:00:00       302.20        70        5.40           clear sky
# 1  2024-11-09 21:00:00       302.01        68        4.78           clear sky
# 2  2024-11-10 00:00:00       301.76        62        4.00           clear sky
# 3  2024-11-10 03:00:00       301.39        57        4.33           clear sky
# 4  2024-11-10 06:00:00       301.89        57        2.86           clear sky

# %%
weather_df['date_time'] = pd.to_datetime(weather_df['date_time'])
weather_df['date'] = weather_df['date_time'].dt.date

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(weather_df,x='date_time',y='temperature',label='temp')
sns.lineplot(weather_df,x='date_time',y='wind_speed',label='wind speed')
sns.lineplot(weather_df,x='date_time',y='humidity',label='humidity')
plt.legend()
plt.show()
# Out:
# /home/leosama/anaconda3/envs/timeseries/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/leosama/anaconda3/envs/timeseries/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/leosama/anaconda3/envs/timeseries/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
print(weather_df['temperature'].mean())
weather_df['temperature'].max(),weather_df['temperature'].min()
# Out:
# 301.7575
# (302.82, 301.02)

# %%
sns.scatterplot(x=weather_df['temperature'],y=weather_df['humidity'])
# Out:
# <Axes: xlabel='temperature', ylabel='humidity'>

# %%
weather_df.set_index(weather_df['date_time'],inplace=True)

# %%
daily_mean_temp = weather_df['temperature'].resample('D').mean()
daily_mean_humidity = weather_df['humidity'].resample('D').mean()
daily_mean_wind_speed = weather_df['wind_speed'].resample('D').mean()

# %%
daily_mean_temp.plot(marker='o')
# Out:
# <Axes: xlabel='date_time'>
